# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# importation du dataset

# %%
df = pd.read_csv('salesData.csv')

# %% [markdown]
# analyse des données

# %%
df.head()
# Out:
#     OrderID               Product  QuantityOrdered  PriceEach  \
# 0  295665.0    Macbook Pro Laptop              1.0    1700.00
# 1  295666.0    LG Washing Machine              1.0     600.00
# 2  295667.0  USB-C Charging Cable              1.0        NaN
# 3  295668.0      27in FHD Monitor              1.0     149.99
# 4  295669.0  USB-C Charging Cable              1.0      11.95
#
#              OrderDate  Day  Month  Year  \
# 0  2019-12-30 00:01:00   30     12  2019
# 1  2019-12-29 07:03:00   29     12  2019
# 2  2019-12-12 18:21:00   12     12  2019
# 3  2019-12-22 15:13:00   22     12  2019
# 4  2019-12-18 12:38:00   18     12  2019
#
#                           PurchaseAddress
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
df.shape
# Out:
# (185687, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185687 entries, 0 to 185686
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   OrderID          185687 non-null  float64
#  1   Product          185687 non-null  object
#  2   QuantityOrdered  185672 non-null  float64
#  3   PriceEach        185681 non-null  float64
#  4   OrderDate        185687 non-null  object
#  5   Day              185687 non-null  int64
#  6   Month            185687 non-null  int64
#  7   Year             185687 non-null  int64
#  8   PurchaseAddress  185687 non-null  object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.8+ MB

# %%
df.describe()
# Out:
#              OrderID  QuantityOrdered      PriceEach            Day  \
# count  185687.000000    185672.000000  185681.000000  185687.000000
# mean   230411.376227         1.124553     184.523870      15.758723
# std     51511.578477         0.443084     332.847132       8.782079
# min    141234.000000         1.000000       2.990000       1.000000
# 25%    185833.500000         1.000000      11.950000       8.000000
# 50%    230355.000000         1.000000      14.950000      16.000000
# 75%    275028.500000         1.000000     150.000000      23.000000
# max    319670.000000         9.000000    1700.000000      31.000000
#
#                Month           Year
# count  185687.000000  185687.000000
# mean        7.058679    2019.000183
# std         3.502942       0.013530
# min         1.000000    2019.000000
# 25%         4.000000    2019.000000
# 50%         7.000000    2019.000000
# 75%        10.000000    2019.000000
# max        12.000000    2020.000000

# %% [markdown]
# vérification des valeurs manquantes

# %%
df.isnull().sum()
# Out:
# OrderID             0
# Product             0
# QuantityOrdered    15
# PriceEach           6
# OrderDate           0
# Day                 0
# Month               0
# Year                0
# PurchaseAddress     0
# dtype: int64

# %% [markdown]
# Traitement des valeurs manquantes
# ---

# %%
#remplacer les valeurs manquantes
df.isna().sum()
# Out:
# OrderID             0
# Product             0
# QuantityOrdered    15
# PriceEach           6
# OrderDate           0
# Day                 0
# Month               0
# Year                0
# PurchaseAddress     0
# dtype: int64

# %%
df
# Out:
#          OrderID                 Product  QuantityOrdered  PriceEach  \
# 0       295665.0      Macbook Pro Laptop              1.0    1700.00
# 1       295666.0      LG Washing Machine              1.0     600.00
# 2       295667.0    USB-C Charging Cable              1.0        NaN
# 3       295668.0        27in FHD Monitor              1.0     149.99
# 4       295669.0    USB-C Charging Cable              1.0      11.95
# ...          ...                     ...              ...        ...
# 185682  222905.0  AAA Batteries (4-pack)              1.0       2.99
# 185683  222906.0        27in FHD Monitor              1.0     149.99
# 185684  222907.0    USB-C Charging Cable              1.0      11.95
# 185685  222908.0    USB-C Charging Cable              1.0      11.95
# 185686  222909.0  AAA Batteries (4-pack)              1.0       2.99
#
#                   OrderDate  Day  Month  Year  \
# 0       2019-12-30 00:01:00   30     12  2019
# ...

# %% [markdown]
# vue le faible pourcentage des valeurs manquantes, nous pouvons proceder à  leur suppressions

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 185682    False
# 185683    False
# 185684    False
# 185685    False
# 185686    False
# Length: 185687, dtype: bool

# %%
#suppression des valeurs manquantes
df.columns
# Out:
# Index(['OrderID', 'Product', 'QuantityOrdered', 'PriceEach', 'OrderDate',
#        'Day', 'Month', 'Year', 'PurchaseAddress'],
#       dtype='object')

# %%
# chercher les colonnes cotegorielle

# %%
df.select_dtypes('number')
# Out:
#          OrderID  QuantityOrdered  PriceEach  Day  Month  Year
# 0       295665.0              1.0    1700.00   30     12  2019
# 1       295666.0              1.0     600.00   29     12  2019
# 2       295667.0              1.0        NaN   12     12  2019
# 3       295668.0              1.0     149.99   22     12  2019
# 4       295669.0              1.0      11.95   18     12  2019
# ...          ...              ...        ...  ...    ...   ...
# 185682  222905.0              1.0       2.99    7      6  2019
# 185683  222906.0              1.0     149.99    1      6  2019
# 185684  222907.0              1.0      11.95   22      6  2019
# 185685  222908.0              1.0      11.95   26      6  2019
# 185686  222909.0              1.0       2.99   25      6  2019
#
# [185687 rows x 6 columns]

# %%
num_feature = df.select_dtypes(include=['int64','float64']).columns
cat_feature = df.select_dtypes(include=['object']).columns

# %%
#trier les valeurs manquantes du plus grand au plus petit pour les 10 premies
df.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# QuantityOrdered    15
# PriceEach           6
# OrderID             0
# Product             0
# OrderDate           0
# Day                 0
# Month               0
# Year                0
# PurchaseAddress     0
# dtype: int64

# %%
#remplacer les valeurs manquantes pas la moyenne ou la mediane de la colonne
for i in num_feature:
  print(i)
  df[i].fillna(df[i].median(), inplace= True)
# Out:
# OrderID
# QuantityOrdered
# PriceEach
# Day
# Month
# Year

# %%
for i in cat_feature:
  print(i)
  df[i].fillna('none', inplace= True)
# Out:
# Product
# OrderDate
# PurchaseAddress

# %%
#vérification de la suppression des valeurs manquantes
df.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# OrderID            0
# Product            0
# QuantityOrdered    0
# PriceEach          0
# OrderDate          0
# Day                0
# Month              0
# Year               0
# PurchaseAddress    0
# dtype: int64

# %%
df.shape
# Out:
# (185687, 9)

# %% [markdown]
# **Traitement des valeurs aberantes**

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
#selection des variables ayant des variables aberrantes
df[['QuantityOrdered','PriceEach']].boxplot()
# Out:
# <Axes: >

# %%
features = ('QuantityOrdered','PriceEach')

# %%
#ALGO POUR REMPLACER LES OUTLIERS
def impute_outliers(df, feature):
    q1 = np.percentile(df[feature], 25)
    q3 = np.percentile(df[feature], 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5*iqr
    upper_bound = q3 + 1.5*iqr

    df.loc[(df[feature] < lower_bound), feature] = lower_bound
    df.loc[(df[feature] > upper_bound), feature] = upper_bound

# %%
#REMPLACER L'ENSEMBLES DES VALEURS ABERRANTES
for feature in features:
    impute_outliers(df, feature)

# %%
df.boxplot()
# Out:
# <Axes: >
